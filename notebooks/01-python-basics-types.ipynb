# %% [markdown]
# # Python 기초: 기본 타입
#
# ## 개요
#
# Python의 기본 데이터 타입을 다룹니다. 정수(int), 실수(float), 문자열(str), 불리언(bool), None 타입의 특성과 사용법을 학습합니다.

# %%
# 정수 예제
age = 25
temperature = -10
count = 0

print(type(age))  # <class 'int'>
print(age)        # 25

# %%
# 실수 예제
pi = 3.14159
price = 19.99
temperature = -5.5

print(type(pi))  # <class 'float'>
print(pi)        # 3.14159

# %%
# 문자열 예제
name = "홍길동"
greeting = '안녕하세요'
message = "Python은 '간단한' 언어입니다"

print(type(name))  # <class 'str'>
print(name)        # 홍길동

# 여러 줄 문자열
multiline = """
첫 번째 줄
두 번째 줄
세 번째 줄
"""

# %%
# 불리언 예제
is_active = True
is_completed = False

print(type(is_active))  # <class 'bool'>
print(is_active)        # True

# %%
# None 예제
result = None
data = None

print(type(result))  # <class 'NoneType'>
print(result)        # None

# %%
# 다양한 타입의 변수 선언
age = 25              # 정수
height = 175.5        # 실수
name = "홍길동"       # 문자열
is_student = True     # 불리언
email = None          # None

# 타입 확인
print(f"나이: {age} (타입: {type(age).__name__})")
print(f"키: {height} (타입: {type(height).__name__})")
print(f"이름: {name} (타입: {type(name).__name__})")
print(f"학생 여부: {is_student} (타입: {type(is_student).__name__})")
print(f"이메일: {email} (타입: {type(email).__name__})")
