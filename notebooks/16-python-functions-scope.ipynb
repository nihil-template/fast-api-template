# %% [markdown]
# # Python 기초: 함수 스코프## 개요Python 기초 학습을 위한 실습 노트북입니다.

# %%
# 전역 변수global_var = "전역 변수"def my_function():    # 지역 변수    local_var = "지역 변수"    print(global_var)  # 전역 변수 접근 가능    print(local_var)my_function()# print(local_var)  # 오류! 지역 변수는 함수 밖에서 접근 불가

# %%
count = 0def increment():    global count    count += 1increment()print(count)  # 1

# %%
def outer():    x = "외부 함수"        def inner():        nonlocal x        x = "내부 함수에서 수정"        print(x)        inner()    print(x)outer()
